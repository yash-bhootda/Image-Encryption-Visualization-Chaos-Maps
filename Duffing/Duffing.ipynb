# %%
from PIL import Image
import random
import math
import numpy as np
import cv2 
from matplotlib import pyplot as plt 
import os
from matplotlib.pyplot import imshow
from math import log

# %%
#2-D Duffing map

im = Image.open("flower.jpeg")  # Can be many different formats.
pix = im.load()
m= im.size[0]
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=522x340>

# %%
x1=-0.04
y1=0.2

savex1=[]
savey1=[]


for i in range(m*m*8):
        #Henon Map formula
    xN = y1
    yN = -0.2*x1 + 2.75*y1 - (y1*y1*y1)
    

        # New x = xN and y = yN
    x1 = xN
    y1 = yN
    
    savex1.append(x1)
    savey1.append(y1)

# %%
x2=0.23
y2=-0.13

savex2=[]
savey2=[]

for i in range(m*m*8):
    xN = y2
    yN = -0.2*x2 + 2.75*y2 - (y2*y2*y2)
    

        # New x = xN and y = yN
    x2 = xN
    y2 = yN
    
    savex2.append(x2)
    savey2.append(y2)

# %%
#FINAL X and Y
h1=[]

for i in range(m*m*8):
    if(savex2[i]>savex1[i]):
        h1.append(1)
    else:
        h1.append(0)
        
h2=[]

for i in range(m*m*8):
    if(savey2[i]<savey1[i]):
        h2.append(1)
    else:
        h2.append(0)
        
        
len(h2)
# Out:
# 2179872

# %%
#XORing the secret images generated:

def returningbinarytuples(p):
    binary=[]
    for i in range(8):
        binary.append(int(p%2))
        p=(p-(p%2))/2
        
    binaryreal=[0,0,0,0,0,0,0,0]

    for i in range(8):
        binaryreal[7-i]=binary[i]
    return binaryreal

def dec(bitSequence):
    decimal = 0
    for bit in bitSequence:
        decimal = decimal * 2 + bit
    return decimal

# %%
image_matrix = []
for width in range(m):
    row = []
    for height in range(m):
        try:
            row.append((pix[height,width]))
        except:
            row=[pix[height,width]]
    try:
        image_matrix.append(row)
    except:
        image_matrix = [row]
        
img2=image_matrix
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Projects\ISM\Chaotic-Map-Image-Encrpytion-master\Chaotic-Map-Image-Encrpytion-master\Duffing.ipynb Cell 7 in 6
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> try:
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>     row.append((pix[height,width]))
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> except:
#
# IndexError: image index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# d:\Projects\ISM\Chaotic-Map-Image-Encrpytion-master\Chaotic-Map-Image-Encrpytion-master\Duffing.ipynb Cell 7 in 8
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>         row.append((pix[height,width]))
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>     except:
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>         row=[pix[height,width]]
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> try:
#      <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>     image_matrix.append(row)
#
# IndexError: image index out of range

# %%
img2 = image_matrix

for j in range(20):
   for x in range(m):
       for y in range(m):

           img2[x][y] = image_matrix[(x+y)%m][(x+2*y)%m]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Projects\ISM\Chaotic-Map-Image-Encrpytion-master\Chaotic-Map-Image-Encrpytion-master\Duffing.ipynb Cell 8 in 7
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> for x in range(m):
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     for y in range(m):
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>         img2[x][y] = image_matrix[(x+y)%m][(x+2*y)%m]
#
# IndexError: list index out of range

# %%
#RED PLANE

imagebitwise=[]

for i in range(m):
    for j in range(m):
        queen=returningbinarytuples(img2[i][j][0])
        for k in range (8):
            imagebitwise.append(queen[k])
            
r=[]

for i in range (m*m*8):
    r.append(imagebitwise[i]^h1[i]^h2[i])
len(r)


# GREEN PLANE X
imagebitwise=[]

for i in range(m):
    for j in range(m):
        queen=returningbinarytuples(img2[i][j][1])
        for k in range (8):
            imagebitwise.append(queen[k])
            
g=[]

for i in range (m*m*8):
    g.append(imagebitwise[i]^h1[i]^h2[i])
len(g)


#BLUE PLANE X

imagebitwise=[]

for i in range(m):
    for j in range(m):
        queen=returningbinarytuples(img2[i][j][1])
        for k in range (8):
            imagebitwise.append(queen[k])
            
b=[]

for i in range (m*m*8):
    b.append(imagebitwise[i]^h1[i]^h2[i])

len(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Projects\ISM\Chaotic-Map-Image-Encrpytion-master\Chaotic-Map-Image-Encrpytion-master\Duffing.ipynb Cell 9 in 7
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> for i in range(m):
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     for j in range(m):
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>         queen=returningbinarytuples(img2[i][j][0])
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>         for k in range (8):
#       <a href='vscode-notebook-cell:/d%3A/Projects/ISM/Chaotic-Map-Image-Encrpytion-master/Chaotic-Map-Image-Encrpytion-master/Duffing.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>             imagebitwise.append(queen[k])
#
# NameError: name 'img2' is not defined

# %%
r=np.reshape(r,(m*m,8))
g=np.reshape(g,(m*m,8))
b=np.reshape(b,(m*m,8))

# %%
encrypted1=[]
encryprow=[]
for i in range(1,(m*m)+1):
    try:
        r1=dec(r[i-1])
        g1=dec(g[i-1])
        b1=dec(b[i-1])
        encryprow.append((r1,g1,b1))
        if(i%m==0):
            encrypted1.append(encryprow)
            encryprow=[]
        
    except:
       ;

# %%
len(encrypted1)
# Out:
# 250

# %%
im5 = Image.new("L", (m, m))
rgb_im = im5.convert('RGBA')
pix = rgb_im.load()

for x in range(m):
    for y in range(m):
        pix[x, y] = encrypted1[x][y]
rgb_im.save("duffingencrypted1.bmp", "BMP")

# %%
img = Image.open("./duffingencrypted1.bmp")
img
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=250x250>

# %%
samples_x = []
samples_y = []
for i in range(1024):
    x = random.randint(0,m-2)
    y = random.randint(0,m-1)
    samples_x.append(encrypted1[x][y])
    samples_y.append(encrypted1[x+1][y])
plt.figure(figsize=(10,8))
plt.scatter(samples_x,samples_y,s=2)
plt.title('Adjacent Pixel Autocorrelation - Duffing Encrypted', fontsize=20)
plt.show()

# %%
img = cv2.imread("duffingencrypted1.bmp",1) 
pil_im = Image.open("duffingencrypted1.bmp", 'r')
imshow(np.asarray(pil_im))

plt.figure(figsize=(14,6))
histogram_blue = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(histogram_blue, color='blue') 
histogram_green = cv2.calcHist([img],[1],None,[256],[0,256]) 
plt.plot(histogram_green, color='green') 
histogram_red = cv2.calcHist([img],[2],None,[256],[0,256]) 
plt.plot(histogram_red, color='red') 
plt.title('Intensity Histogram - Duffing Encrypted', fontsize=20)
plt.xlabel('pixel values', fontsize=16)
plt.ylabel('pixel count', fontsize=16) 
plt.show()

# %%
#DECRYPTION PROCESS:

#2-D Duffing map



im = Image.open("duffingencrypted1.bmp")  # Can be many different formats.
pix = im.load()
m= im.size[0]

# %%
image_matrix = []
for width in range(m):
    row = []
    for height in range(m):
        try:
            row.append((pix[width,height]))
        except:
            row=[pix[width, height]]
    try:
        image_matrix.append(row)
    except:
        image_matrix = [row]

# %%
#RED PLANE

imagebitwise=[]

for i in range(m):
    for j in range(m):
        queen=returningbinarytuples(image_matrix[i][j][0])
        for k in range (8):
            imagebitwise.append(queen[k])
            
r=[]

for i in range (m*m*8):
    r.append(imagebitwise[i]^h1[i]^h2[i])
len(r)


# GREEN PLANE X
imagebitwise=[]

for i in range(m):
    for j in range(m):
        queen=returningbinarytuples(image_matrix[i][j][1])
        for k in range (8):
            imagebitwise.append(queen[k])
            
g=[]

for i in range (m*m*8):
    g.append(imagebitwise[i]^h1[i]^h2[i])
len(g)


#BLUE PLANE X

imagebitwise=[]

for i in range(m):
    for j in range(m):
        queen=returningbinarytuples(image_matrix[i][j][1])
        for k in range (8):
            imagebitwise.append(queen[k])
            
b=[]

for i in range (m*m*8):
    b.append(imagebitwise[i]^h1[i]^h2[i])

len(b)
# Out:
# 500000

# %%
r=np.reshape(r,(m*m,8))
g=np.reshape(g,(m*m,8))
b=np.reshape(b,(m*m,8))

decrypted1=[]
decryprow=[]
for i in range(1,(m*m)+1):
    try:
        r1=dec(r[i-1])
        g1=dec(g[i-1])
        b1=dec(b[i-1])
        decryprow.append((r1,g1,b1))
        if(i%m==0):
            decrypted1.append(decryprow)
            decryprow=[]
        
    except:
       ;

# %%
img2 = image_matrix

#for j in range(750):
 #   for x in range(m):
  #      for y in range(m):

   #         img2[x][y] = decrypted1[(x+y)%m][(x+2*y)%m]

# %%
im5 = Image.new("L", (m, m))
rgb_im = im5.convert('RGBA')
pix = rgb_im.load()

for x in range(m):
    for y in range(m):
        pix[x, y] = img2[x][y]
rgb_im.save("duffingdecrypted1.bmp", "BMP")
